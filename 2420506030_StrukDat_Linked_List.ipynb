# %% [markdown]
# <a href="https://colab.research.google.com/github/Yasabuana/Struktur-Data/blob/main/2420506030_StrukDat_Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Membuat Kelas Node dan Linked List
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %%
# Implementasi Singly Linked List
class SinglyLinkedList:
    def __init__(self) :
        self.head = None

    def insert_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    def display(self):
        temp = self.head
        while temp:
            print(temp.data, end=' -> ')
            temp = temp.next
        print('None')

# %%
# Implementasi Doubly Linked List
class DoublyNode:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def insert_at_end(self, data):
        new_node = DoublyNode(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node
        new_node.prev = temp

    def display(self):
        temp = self.head
        while temp:
            print(temp.data, end=' <->')
            temp = temp.next
        print('None')

# %%
# Implementasi Circular Linked List
class CircularLinkedList:
    def __init__(self):
        self.head = None

    def insert_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            new_node.next = self.head
            return
        temp = self.head
        while temp.next != self.head:
            temp = temp.next
        temp.next = new_node
        new_node.next = self.head

    def display(self):
        if not self.head:
            return
        temp = self.head
        while True:
            print(temp.data, end=' ->')
            temp = temp.next
            if temp == temp.head:
                break
        print('(Back to Head)')

# %% [markdown]
# LANGKAH PRAKTIKUM

# %%
# Definisi Node dalam Linked List
class TaskNode:
    def __init__(self, task_name):
        self.task_name = task_name  # Menyimpan nama tugas
        self.next = None # Pointer ke tugas berikutnya

# Definisi Linked List untuk Daftar Tugas
class TaskList:
    def __init__(self):
        self.head = None  # Awalnya tidak ada tugas (daftar kosong)

        # Menambahkan tugas ke Linked List
    def add_task(self, task_name):
        new_task = TaskNode(task_name)
        if not self.head:
            self.head = new_task  # Jika list kosong, tugas pertama  menjadi head

        else:
            current = self.head
            while current.next:  # Mencari node terakhir dalam list
                current = current.next
            current.next = new_task  # Menambahkan tugas di akhir list

              #Menampilkan daftar tugas
    def show_tasks(self):
          if not self.head:
              print("\n Tifak ada tugas hari ini")
              return

          print("\n Daftar Tugas Hari Ini:")
          current = self.head
          count = 1
          while current:
                print(f"{count}. {current.task_name}")
                current = current.next
                count += 1


# ========== Program Utama ========== #

# Membuat objek daftar tugas
task_list = TaskList()

# Meminta pengguna memasukkan jumlah tugas
num_tasks = int(input("Masukkan jumlah tugas hari ini: "))

# Loop untuk memasukkan tugas ke dalam Linked List
for i in range(1, num_tasks + 1):
    task_name = input(f"Masukkan tugas ke-{i}: ")
    task_list.add_task(task_name)

# Menampilkan hasil daftar tugas
task_list.show_tasks()
# Out:
# Masukkan jumlah tugas hari ini: 3
# Masukkan tugas ke-1: Praktikum Struktur data
# Masukkan tugas ke-2: Basis Data
# Masukkan tugas ke-3: Kalkulus Lanjut
#
#  Daftar Tugas Hari Ini:
# 1. Praktikum Struktur data
# 2. Basis Data
# 3. Kalkulus Lanjut

# %%
# Latihan 1
# Definisi Node dalam Linked List
class TaskNode:
    def __init__(self, task_name):
        self.task_name = task_name  # Menyimpan nama tugas
        self.next = None # Pointer ke tugas berikutnya

# Definisi Linked List untuk Daftar Tugas
class TaskList:
    def __init__(self):
        self.head = None  # Awalnya tidak ada tugas (daftar kosong)

        # Menambahkan tugas ke Linked List
    def add_task(self, task_name):
        new_task = TaskNode(task_name)
        if not self.head:
            self.head = new_task  # Jika list kosong, tugas pertama  menjadi head

        else:
            current = self.head
            while current.next:  # Mencari node terakhir dalam list
                current = current.next
            current.next = new_task  # Menambahkan tugas di akhir list

              #Menampilkan daftar tugas
    def show_tasks(self):
          if not self.head:
              print("\n Tidak ada jadwal tugas di hari jumat")
              return

          print("\n Daftar jadwal di hari jumat:")
          current = self.head
          count = 1
          while current:
                print(f"{count}. {current.task_name}")
                current = current.next
                count += 1


# ========== Program Utama ========== #

# Membuat objek daftar tugas
task_list = TaskList()

# Meminta pengguna memasukkan jumlah tugas
num_tasks = int(input("Masukkan NPM Anda: "))

# Loop untuk memasukkan tugas ke dalam Linked List
for i in range(1, (num_tasks % 10) + 1):
    task_name = input(f"Masukkan Jadwal ke-{i}: ")
    task_list.add_task(task_name)

# Menampilkan hasil daftar tugas
task_list.show_tasks()
# Out:
# Masukkan NPM Anda: 2420506030
#
#  Tidak ada jadwal tugas di hari jumat

# %%
# Implementasi Doubly Linked List
# Definisi Node dalam Doubly Linked List

class PageNode:
    def __init__(self,url):
        self.url = url  # URL halaman web
        self.next = None  # Pointer ke halaman berikutnya
        self.prev = None  # Pointer ke halaman sebelumnya

#Definisi Doubly Linke list untuk riwayat peramban
class BrowserHistory:
    def __init__(self):
        self.head = None  # Awalnya tidak ada halaman di riwayat
        self.current = None  # Pointer ke halaman yang sedang ditampilkan

    # Menambah halaman baru ke dalam riwayat
    def visit_page(self,url):
        new_page = PageNode(url)
        if not self.current:
            self.current = new_page

        else:
            new_page.prev = self.current
            self.current.next = new_page
            self.current = new_page  # pindahkan posisi ke halaman baru

      # Menampilkan riwayat kunjungan
    def show_history(self):
        if not self.current:
            print("\n Riwayat kosong")
            return

        print("\n Riwayat peramban web:")
        temp = self.current
        while temp.prev:  #kembali ke halaman pertama
            temp = temp.prev

        count = 1
        while temp:
            print(f"{count}. {temp.url}")
            temp = temp.next
            count += 1

    # Navigasi munder ke halaman sebelumnya
    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"\n Anda kembali ke: {self.current.url}")
        else:
            print("\n tidak bisa kembali, ini adalah halaman pertama")

    # Navigasi maju ke halaman berikutnya
    def go_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"\n Anda maju ke: {self.current.url}")
        else:
            print("\n Tidak bisa maju, ini adalah halaman terakhir!")


#====== Program Utama =======#

#Membuat objek riwayat peramban
history = BrowserHistory()

#Meminta pengguna memasukkan jumlah halaman yang dikunjungi
num_pages = int(input("\nMasukkan jumlah halaman yang dikunjungi: "))

# Loop untuk memasukkan URL halaman ke dalam Doubly Linked List
for i in range(1, num_pages + 1):
    url = input(f"Masukkan URL halaman ke-{i}: ")
    history.visit_page(url)

# Menampilkan riwayat yang telah dimasukkan
history.show_history()

# Menu navigasi pengguna
while True:
    command = input("\n Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.\nMasukkan perintah: ").lower()

    if command == 'b' :
        history.go_back()
    elif command == 'f':
        history.go_forward()
    elif command == 'x':
        print("\n Keluar dari riwayat peramban.")
        break
    else:
          print("\n Perintah  tidak dikenal")
# Out:
# Masukkan jumlah halaman yang dikunjungi: 2
# Masukkan URL halaman ke-1: https://github.com/Yasabuana
# Masukkan URL halaman ke-2: https://github.com/Yasabuana/Struktur-Data
#
#  Riwayat peramban web:
# 1. https://github.com/Yasabuana
# 2. https://github.com/Yasabuana/Struktur-Data
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: b
#
#  Anda kembali ke: https://github.com/Yasabuana
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: b
#
#  tidak bisa kembali, ini adalah halaman pertama
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: x
#
#  Keluar dari riwayat peramban.

# %%
#Latihan 2
class FileNode:
    def __init__(self, File):
        self.File = File  # URL halaman web
        self.next = None  # Pointer ke halaman berikutnya
        self.prev = None  # Pointer ke halaman sebelumnya

#Definisi Doubly Linke list untuk riwayat peramban
class FileHistory:
    def __init__(self):
        self.head = None  # Awalnya tidak ada halaman di riwayat
        self.current = None  # Pointer ke halaman yang sedang ditampilkan

    # Menambah halaman baru ke dalam riwayat
    def visit_file(self,File):
        new_file = FileNode(File)
        if not self.current:
            self.current = new_file

        else:
            new_file.prev = self.current
            self.current.next = new_file
            self.current = new_file  # pindahkan posisi ke halaman baru

      # Menampilkan riwayat kunjungan
    def show_history(self):
        if not self.current:
            print("\n Riwayat kosong")
            return

        print("\n Riwayat Folder:")
        temp = self.current
        while temp.prev:  #kembali ke halaman pertama
            temp = temp.prev

        count = 1
        while temp:
            print(f"{count}. {temp.File}")
            temp = temp.next
            count += 1

    # Navigasi munder ke halaman sebelumnya
    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"\n Anda kembali ke: {self.current.File}")
        else:
            print("\n tidak bisa kembali, ini adalah file pertama")

    # Navigasi maju ke halaman berikutnya
    def go_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"\n Anda maju ke: {self.current.File}")
        else:
            print("\n Tidak bisa maju, ini adalah file terakhir!")


#====== Program Utama =======#

#Membuat objek riwayat peramban
history = FileHistory()

#Meminta pengguna memasukkan jumlah halaman yang dikunjungi
num_files = int(input("\nMasukkan jumlah folder yang ingin anda navigasi: "))

# Loop untuk memasukkan URL halaman ke dalam Doubly Linked List
for i in range(1, (num_files % 10)+ 1):
    File = input(f"Masukkan folder ke-{i}: ")
    history.visit_file(File)

# Menampilkan riwayat yang telah dimasukkan
history.show_history()

# Menu navigasi pengguna
while True:
    command = input("\n Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.\nMasukkan perintah: ").lower()

    if command == 'b' :
        history.go_back()
    elif command == 'f':
        history.go_forward()
    elif command == 'x':
        print("\n Keluar dari riwayat file.")
        break
    else:
          print("\n Perintah  tidak dikenal")
# Out:
# Masukkan jumlah folder yang ingin anda navigasi: 2
# Masukkan folder ke-1: p
# Masukkan folder ke-2: q
#
#  Riwayat Folder:
# 1. p
# 2. q
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: b
#
#  Anda kembali ke: p
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: b
#
#  tidak bisa kembali, ini adalah file pertama
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: p
#
#  Perintah  tidak dikenal
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: f
#
#  Anda maju ke: q
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Masukkan perintah: f
#
#  Tidak bisa maju, ini adalah file terakhir!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3011e45ffc07> in <cell line: 0>()
#      75 # Menu navigasi pengguna
#      76 while True:
# ---> 77     command = input("\n Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.\nMasukkan perintah: ").lower()
#      78
#      79     if command == 'b' :
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Definisi Node dalam Singly Linked List
class Node:
    def __init__(self, data):
        self.data = data  # Menyimpan nilai node
        self.next = None  # Pointer ke node berikutnya

# Definisi Singly Linked List dengan Berbagai Operasi
class LinkedList:
    def __init__(self):
        self.head = None  # Awalnya, daftar kosong

    # Menambahkan elemen di awal
    def add_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    # Menambahkan elemen di akhir
    def add_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    # Menambahkan elemen di posisi tertentu
    def add_at_position(self, position, data):
        if position < 0:
            print("Posisi tidak valid!")
            return
        new_node = Node(data)
        if position == 0:
            self.add_at_beginning(data)
            return
        temp = self.head
        for _ in range(position - 1):
            if not temp:
                print("Posisi melebihi panjang list!")
                return
            temp = temp.next
        if not temp:
            print("Posisi melebihi panjang list!")
            return
        new_node.next = temp.next
        temp.next = new_node

    # Menghapus elemen di awal
    def delete_at_beginning(self):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus!")
            return
        self.head = self.head.next
        return

    # Menghapus elemen di akhir
    def delete_at_end(self):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if not self.head.next:
            self.head = None
            return
        temp = self.head
        while temp.next.next:
            temp = temp.next
        temp.next = None

    # Menghapus elemen di posisi tertentu
    def delete_at_position(self, position):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if position == 0:
            self.head = self.head.next
            return
        temp = self.head
        for _ in range(position - 1):
            if not temp or not temp.next:
                print("Posisi tidak ditemukan!")
                return
            temp = temp.next
        temp.next = temp.next.next

    # Mencari elemen dalam Linked List
    def search(self, key):
        temp = self.head
        while temp:
            if temp.data == key:
                print(f"Elemen {key} ditemukan dalam daftar!")
                return
            temp = temp.next
        print(f"Elemen {key} tidak ditemukan dalam daftar.")

    # Membalik (reverse) Linked List
    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev

    # Menampilkan Linked List
    def display(self):
        if not self.head:
            print("Daftar kosong!")
            return
        temp = self.head
        while temp:
            print(temp.data, end="->")
            temp = temp.next
        print("None")

# ======== Program Utama (Main) ========

# Membuat objek Linked List
ll = LinkedList()

# Meminta pengguna memasukkan elemen awal
num_elements = int(input("\nMasukkan jumlah awal elemen dalam daftar: "))

for i in range(num_elements):
    data = int(input(f"Masukkan data ke-{i+1}: "))
    ll.add_at_end(data)

# Menu Operasi Linked List
while True:
    print("\n Pilih Operasi:")
    print("1. Tambah elemen di awal")
    print("2. Tambah elemen di akhir")
    print("3. Tambah elemen di posisi tertentu")
    print("4. Hapus elemen di awal")
    print("5. Hapus elemen di akhir")
    print("6. Hapus elemen di posisi tertentu")
    print("7. Cari elemen dalam daftar")
    print("8. Balikkan daftar")
    print("9. Tampilkan daftar")
    print("0. Keluar")

    choice = int(input("\nMasukkan pilihan: "))

    if choice == 1:
        data = int(input("Masukkan data yang ingin ditambahkan di awal: "))
        ll.add_at_beginning(data)
    elif choice == 2:
        data = int(input("Masukkan data yang ingin ditambahkan di akhir: "))
        ll.add_at_end(data)
    elif choice == 3:
        position = int(input("Masukkan posisi untuk menambahkan data: "))
        data = int(input("Masukkan data yang ingin ditambahkan: "))
        ll.add_at_position(position, data)
    elif choice == 4:
        ll.delete_at_beginning()
    elif choice == 5:
        ll.delete_at_end()
    elif choice == 6:
        position = int(input("Masukkan posisi elemen yang ingin dihapus: "))
        ll.delete_at_position(position)
    elif choice == 7:
        key = int(input("Masukkan elemen yang ingin dicari: "))
        ll.search(key)
    elif choice == 8:
        ll.reverse()
        print("Daftar berhasil dibalik!")
    elif choice == 9:
        ll.display()
    elif choice == 0:
        print("\nKeluar dari program.")
        break
    else:
        print("\nPilihan tidak valid, silakan coba lagi!")
# Out:
# Masukkan jumlah awal elemen dalam daftar: 3
# Masukkan data ke-1: 7
# Masukkan data ke-2: 5
# Masukkan data ke-3: 2
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 1
# Masukkan data yang ingin ditambahkan di awal: 3
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 2
# Masukkan data yang ingin ditambahkan di akhir: 4
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 3
# Masukkan posisi untuk menambahkan data: 2
# Masukkan data yang ingin ditambahkan: 8
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 4
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 2
# Masukkan data yang ingin ditambahkan di akhir: 4
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 4
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 5
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 6
# Masukkan posisi elemen yang ingin dihapus: 3
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 7
# Masukkan elemen yang ingin dicari: 2
# Elemen 2 ditemukan dalam daftar!
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 8
# Daftar berhasil dibalik!
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 9
# 2->5->8->None
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 8
# Daftar berhasil dibalik!
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 9
# 8->5->2->None
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 0
#
# Keluar dari program.
