# %% [markdown]
# <a href="https://colab.research.google.com/github/Yasabuana/Struktur-Data/blob/main/2420506030_Tugas_StrukDat_Stack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tugas
class Gudang:
    def __init__(self, kapasitas):
        self.kapasitas = kapasitas
        self.tumpukan = []

    def push(self, barang):
        if len(self.tumpukan) < self.kapasitas:
            self.tumpukan.append(barang)
            print(f"Barang '{barang}' ditambahkan ke gudang.")
        else:
            print("Gudang penuh! Tidak bisa menambahkan barang.")

    def pop(self):
        if self.tumpukan:
            barang = self.tumpukan.pop()
            print(f"Barang '{barang}' diambil dari gudang.")
            return barang
        else:
            print("Gudang kosong! Tidak ada barang yang bisa diambil.")
            return None

    def tampilkan_tumpukan(self):
        if self.tumpukan:
            print("Isi tumpukan gudang:")
            for barang in reversed(self.tumpukan):
                print(f"- {barang}")
        else:
            print("Gudang kosong.")


kapasitas_gudang =int(input("Masukkan kapasitas gudang (dua digit terakhir NPM): "))
gudang = Gudang(kapasitas_gudang)

while True:
    print("\nMenu:")
    print("1. Tambah barang (push)")
    print("2. Ambil barang (pop)")
    print("3. Tampilkan isi gudang")
    print("4. Keluar")

    pilihan = input("Masukkan pilihan Anda: ")

    if pilihan == "1":
        barang = input("Masukkan nama barang yang ingin ditambahkan: ")
        gudang.push(barang)
    elif pilihan == "2":
        gudang.pop()
    elif pilihan == "3":
        gudang.tampilkan_tumpukan()
    elif pilihan == "4":
        break
    else:
        print("Pilihan tidak valid. Silakan coba lagi.")

print("Program selesai.")
# Out:
# Masukkan kapasitas gudang (dua digit terakhir NPM): 30
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 1
# Masukkan nama barang yang ingin ditambahkan: kopi
# Barang 'kopi' ditambahkan ke gudang.
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 1
# Masukkan nama barang yang ingin ditambahkan: lele
# Barang 'lele' ditambahkan ke gudang.
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 1
# Masukkan nama barang yang ingin ditambahkan: teh
# Barang 'teh' ditambahkan ke gudang.
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 1
# Masukkan nama barang yang ingin ditambahkan: galon
# Barang 'galon' ditambahkan ke gudang.
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 1
# Masukkan nama barang yang ingin ditambahkan: mie goreng rendang
# Barang 'mie goreng rendang' ditambahkan ke gudang.
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 2
# Barang 'mie goreng rendang' diambil dari gudang.
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 3
# Isi tumpukan gudang:
# - galon
# - teh
# - lele
# - kopi
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 2
# Barang 'galon' diambil dari gudang.
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 3
# Isi tumpukan gudang:
# - teh
# - lele
# - kopi
#
# Menu:
# 1. Tambah barang (push)
# 2. Ambil barang (pop)
# 3. Tampilkan isi gudang
# 4. Keluar
# Masukkan pilihan Anda: 4
# Program selesai.
